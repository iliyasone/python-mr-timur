# %% [markdown]
# #### Task 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x, y, z, w):
    return ((x <= y) <= z) or (not w)

print('x y z w F')
for x in (0, 1):
    for y in (0, 1):
        for z in (0, 1):
            for w in (0, 1):
                if not f(x, y, z, w):
                    print(x, y, z, w, int(f(x,y,z,w)))
# Out:
# x y z w F
# 0 0 0 1 0
# 0 1 0 1 0
# 1 1 0 1 0

# %%
0 or 5
# Out:
# 5
