# %%
10+26+26
# Out:
# 62

# %%
per_second = (10**9)
per_year = per_second*60*60*24*365
per_humanity = per_year*8*10**9

62**64//per_humanity
# Out:
# 20472530837634961548171751885612848292220234122378210461370515427877987121238375706587565

# %%
import requests
import json
# API_KEY=""

json_url = "https://api.thecatapi.com/v1/images/searchd?limit=10&api_key=REPLACE_ME"
url = "https://cdn2.thecatapi.com/images/"

# %%
response = requests.get("https://api.thecatapi.com/vsdgww")

# %%
response.content
# Out:
# b'{"message":"404 - please consult the documentation for correct url to call. https://docs.thecatapi.com/"}'

# %%
response.status_code
# Out:
# 400

# %%
response.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 response.raise_for_status()
#
# File c:\Users\iliya\Repositories\students\python-mr-timur\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.thecatapi.com/vsdgww

# %%
obj: dict = response.json()

# %%
print(response.text)
# Out:
# {"message":"404 - please consult the documentation for correct url to call. https://docs.thecatapi.com/"}

# %%
obj = {"1": (1, 2, 3), "2": None, "3": False}

# %%
import json

with open('my_log.py', 'w') as file:
    file.write(str(obj))

# %%
requests.get(json_url)
# Out:
# b"Couldn't find an image matching the passed 'id' of searchd"

# %%
import json

with open('my_log.exe') as file:
    json.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 3
#       1 import json
# ----> 3 with open('my_log.exe') as file:
#       4     json.load(file)
#
# File c:\Users\iliya\Repositories\students\python-mr-timur\.venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_log.exe'

# %%
type A = list[A]
a: A = []
a.append(a)

# %%
b = a[0][0][0][0][0]

# %%
import asyncio


async def test_await():
    print("Before sleep")
    await asyncio.sleep(10)
    print("After sleep")

async def bomb(name: str, start=3):
    for i in range(start, 0, -1):
        print(name, i, sep='-')
        await asyncio.sleep(3)
    print(name, "BOOM", sep='-')

    return start


async def errorish_task():
    raise RuntimeError("Error!")

# %%
for i in range(1, 3+1):
    await bomb(str(i), i)

# %%
jobs = []
for i in range(1, 3+1):
    jobs.append( bomb(str(i), i) )

await asyncio.gather(*jobs)
print("all jobs done")
# Out:
# 1-1
# 2-2
# 3-3
# 1-BOOM
# 2-1
# 3-2
# 2-BOOM
# 3-1
# 3-BOOM
# [1, 2, 3]

# %%
await asyncio.gather(
    task
)
# Out:
# [10]
